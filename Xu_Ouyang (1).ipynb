# %%
# !huggingface-cli login --token XXXXXXXXXXX
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `read` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `read`

# %%
from transformers import pipeline
import torch

messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe = pipeline("text-generation", model="shuyuej/MedLLaMA3-70B-base-INT2-GPTQ", device_map="auto")
pipe(messages)
# Out:
# config.json:   0%|          | 0.00/706 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/22.6G [00:00<?, ?B/s]

# %%
shuyuej/c4ai-command-r7b-12-2024-GPTQ

# %%
# !pip install optimum
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 30.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 30.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install -q -U  auto-gptq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.4 MB/s eta 0:00:00

# %%
from transformers import pipeline
import torch

messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe = pipeline("text-generation", model="Xu-Ouyang/Llama-3.2-3B-int2-GPTQ-wikitext2", device_map="auto")
pipe(messages)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
import torch

from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/Llama-3.2-3B-int2-GPTQ-wikitext2"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)








text = "Hello my name is"
inputs = tokenizer(text, return_tensors="pt").to(0)

out = model.generate(**inputs, max_new_tokens=50, do_sample=True)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Hello my name is a.... to [...??
#  enhnesh...?2?
# 3
# r3
# "Linl....L K"..''z-N..il6q,keril lqq, qqit

# %%
text = "Hello my name is"
inputs = tokenizer(text, return_tensors="pt").to(0)

out = model.generate(**inputs, max_new_tokens=50, do_sample=True)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Hello my name is a...!!TheopclW…
# I'surletkie| ices-Incit=0...... to a welltondskwundl…Tokwfthth,,, heust heallyus

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Xu-Ouyang/Llama-3.2-3B-int2-GPTQ-wikitext2"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "Give me a short introduction to large language model."
messages = [
    {"role": "system", "content": "You are Qwen, created by Alibaba Cloud. You are a helpful assistant."},
    {"role": "user", "content": prompt},
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=10,
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Xu-Ouyang/Llama-3.2-3B-int2-GPTQ-wikitext2"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "Give me a short introduction to large language model."

# Define a chat template
chat_template = """<s>[INST] <<SYS>>
You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
<</SYS>>

{prompt} [/INST]"""  # or {user} [/INST]

# Apply the chat template
text = chat_template.format(prompt=prompt)  # or user=prompt

model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=50,
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(response)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Xu-Ouyang/Llama-3.2-3B-int2-GPTQ-wikitext2"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "Who is Napoleon Bonaparte?"

# Define a chat template
chat_template = """<s>[INST] <<SYS>>
You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
<</SYS>>

{prompt} [/INST]"""  # or {user} [/INST]

# Apply the chat template
text = chat_template.format(prompt=prompt)  # or user=prompt

model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=50,
    do_sample=True,
    top_p=0.5,
    temperature=0.2,
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(response)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Xu-Ouyang/pythia-12b-deduped-int2-step20000-GPTQ-wikitext2"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

prompt = "Who is Napoleon Bonaparte?"

# Define a chat template
chat_template = """<s>[INST] <<SYS>>
You are Qwen, created by Alibaba Cloud. You are a helpful assistant.
<</SYS>>

{prompt} [/INST]"""  # or {user} [/INST]

# Apply the chat template
text = chat_template.format(prompt=prompt)  # or user=prompt

model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=50,
    do_sample=True,
    top_p=0.5,
    temperature=0.2,
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
print(response)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %% [markdown]
# aشغال

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/pythia-12b-deduped-int2-step20000-GPTQ-wikitext2"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
text = "Hello my name is"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

out = model.generate(**inputs, max_new_tokens=5)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %% [markdown]
# شغال

# %%
text = "Who is Napoleon Bonaparte?"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

out = model.generate(**inputs, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Who is Napoleon Bonaparte?
#
# Napoleon Bonaparte is a fictional character who is the protagonist of the novel The Adventures of Napoleon. He is a French aristocrat who is the son of the Duke of Orleans. He is the son of the Duke of Orleans. He is the son

# %%
text = "Archimedes is "

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

out = model.generate(**inputs, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Archimedes is
# a Greek word for "tooth" and is used to describe the
#
# *
#
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [

# %% [markdown]
# ### ayhgشغال

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/pythia-12b-deduped-int2-step20000-GPTQ-wikitext2"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
text = "Who is Napoleon Bonaparte?"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

out = model.generate(**inputs, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))

# %% [markdown]
# شغال جيد

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/Llama-3.2-3B-int4-GPTQ-wikitext2"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
text = "Who is Napoleon Bonaparte?"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

out = model.generate(**inputs, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=50,
    do_sample=True,
    top_p=0.5,
    temperature=0.2,
)

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/Llama-3.2-3B-int4-GPTQ-wikitext2"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
text = "Who is Napoleon Bonaparte?"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

out = model.generate(**inputs, do_sample=True, top_p=0.5, temperature=0.2, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/Bitnet-Llama-70M"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
text = "Who is Napoleon Bonaparte?"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

out = model.generate(**inputs, do_sample=True, top_p=0.5, temperature=0.2, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/722 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/310M [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/Bitnet-Llama-70M"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
text = "Who is Napoleon Bonaparte?"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

# Perform greedy decoding instead of sampling
out = model.generate(**inputs, do_sample=False, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Some weights of LlamaForCausalLM were not initialized from the model checkpoint at Xu-Ouyang/Bitnet-Llama-70M and are newly initialized: ['model.layers.0.input_layernorm.weight', 'model.layers.1.input_layernorm.weight', 'model.layers.2.input_layernorm.weight', 'model.layers.3.input_layernorm.weight', 'model.layers.4.input_layernorm.weight', 'model.layers.5.input_layernorm.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Who is Napoleon Bonaparte?

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

model_id = "Xu-Ouyang/pythia-12b-deduped-int8-step8-GPTQ-wikitext2"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(model_id)
text = "Who is Napoleon Bonaparte?"

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

# Perform greedy decoding instead of sampling
out = model.generate(**inputs, do_sample=True, top_p=0.5, temperature=0.2, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/auto_gptq/nn_modules/triton_utils/kernels.py:410: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd
# ...

# %%
text = "Napoleon Bonaparte is "

# Instead of directly using .to(0), use the model's device
inputs = tokenizer(text, return_tensors="pt").to(model.device)

# Perform greedy decoding instead of sampling
out = model.generate(**inputs, do_sample=True, top_p=0.5, temperature=0.2, max_new_tokens=55)
print(tokenizer.decode(out[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# Napoleon Bonaparte is.
